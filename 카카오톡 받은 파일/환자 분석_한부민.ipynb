# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataP = pd.read_csv('../data/PatientInfo.csv')

# %%
dataP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 14 columns):
# patient_id            5165 non-null int64
# sex                   4043 non-null object
# age                   3785 non-null object
# country               5165 non-null object
# province              5165 non-null object
# city                  5071 non-null object
# infection_case        4246 non-null object
# infected_by           1346 non-null object
# contact_number        791 non-null object
# symptom_onset_date    690 non-null object
# confirmed_date        5162 non-null object
# released_date         1587 non-null object
# deceased_date         66 non-null object
# state                 5165 non-null object
# dtypes: int64(1), object(13)
# memory usage: 565.0+ KB

# %%
dataP
# Out:
#       patient_id     sex  age        country          province          city  \
# 0     1000000001    male  50s          Korea             Seoul    Gangseo-gu
# 1     1000000002    male  30s          Korea             Seoul   Jungnang-gu
# 2     1000000003    male  50s          Korea             Seoul     Jongno-gu
# 3     1000000004    male  20s          Korea             Seoul       Mapo-gu
# 4     1000000005  female  20s          Korea             Seoul   Seongbuk-gu
# 5     1000000006  female  50s          Korea             Seoul     Jongno-gu
# 6     1000000007    male  20s          Korea             Seoul     Jongno-gu
# 7     1000000008    male  20s          Korea             Seoul           etc
# 8     1000000009    male  30s          Korea             Seoul     Songpa-gu
# 9     1000000010  female  60s          Korea             Seoul   Seongbuk-gu
# 10    1000000011  female  50s          China             Seoul  Seodaemun-gu
# ...

# %%
dataP2 = dataP.iloc[:, [2,10,11]].dropna(axis=0).copy()

# %%
dataP2
# Out:
#       age confirmed_date released_date
# 0     50s     2020-01-23    2020-02-05
# 1     30s     2020-01-30    2020-03-02
# 2     50s     2020-01-30    2020-02-19
# 3     20s     2020-01-30    2020-02-15
# 4     20s     2020-01-31    2020-02-24
# 5     50s     2020-01-31    2020-02-19
# 6     20s     2020-01-31    2020-02-10
# 7     20s     2020-02-02    2020-02-24
# 8     30s     2020-02-05    2020-02-21
# 9     60s     2020-02-05    2020-02-29
# 10    50s     2020-02-06    2020-02-29
# 11    20s     2020-02-07    2020-02-27
# 13    60s     2020-02-16    2020-03-12
# 15    70s     2020-02-19    2020-03-11
# 16    70s     2020-02-20    2020-03-01
# 18    70s     2020-02-20    2020-03-08
# 20    80s     2020-02-20    2020-03-08
# 23    40s     2020-02-22    2020-03-14
# 25    30s     2020-02-22    2020-03-11
# 26    50s     2020-02-23    2020-03-04
# 27    70s     2020-02-23    2020-03-11
# 28    20s     2020-02-26    2020-03-11
# 30    50s     2020-02-22    2020-03-19
# ...

# %%
dataP2["confirmed_date"] = dataP2["confirmed_date"].astype('datetime64[ns]')
dataP2["released_date"] = dataP2["released_date"].astype('datetime64[ns]')

# %%
dataP2['days'] = dataP2['released_date'] - dataP2['confirmed_date']
dataP2
# Out:
#       age confirmed_date released_date    days
# 0     50s     2020-01-23    2020-02-05 13 days
# 1     30s     2020-01-30    2020-03-02 32 days
# 2     50s     2020-01-30    2020-02-19 20 days
# 3     20s     2020-01-30    2020-02-15 16 days
# 4     20s     2020-01-31    2020-02-24 24 days
# 5     50s     2020-01-31    2020-02-19 19 days
# 6     20s     2020-01-31    2020-02-10 10 days
# 7     20s     2020-02-02    2020-02-24 22 days
# 8     30s     2020-02-05    2020-02-21 16 days
# 9     60s     2020-02-05    2020-02-29 24 days
# 10    50s     2020-02-06    2020-02-29 23 days
# 11    20s     2020-02-07    2020-02-27 20 days
# 13    60s     2020-02-16    2020-03-12 25 days
# 15    70s     2020-02-19    2020-03-11 21 days
# 16    70s     2020-02-20    2020-03-01 10 days
# 18    70s     2020-02-20    2020-03-08 17 days
# 20    80s     2020-02-20    2020-03-08 17 days
# 23    40s     2020-02-22    2020-03-14 21 days
# 25    30s     2020-02-22    2020-03-11 18 days
# ...

# %%
dataP2.groupby('age').count()
# Out:
#       confirmed_date  released_date  days
# age
# 0s                19             19    19
# 100s               1              1     1
# 10s               65             65    65
# 20s              409            409   409
# 30s              211            211   211
# 40s              241            241   241
# 50s              300            300   300
# 60s              173            173   173
# 70s               83             83    83
# 80s               60             60    60
# 90s               14             14    14

# %%
dataP2["days"] = dataP2["days"].astype('int64')
dataP2
# Out:
#       age confirmed_date released_date              days
# 0     50s     2020-01-23    2020-02-05  1123200000000000
# 1     30s     2020-01-30    2020-03-02  2764800000000000
# 2     50s     2020-01-30    2020-02-19  1728000000000000
# 3     20s     2020-01-30    2020-02-15  1382400000000000
# 4     20s     2020-01-31    2020-02-24  2073600000000000
# 5     50s     2020-01-31    2020-02-19  1641600000000000
# 6     20s     2020-01-31    2020-02-10   864000000000000
# 7     20s     2020-02-02    2020-02-24  1900800000000000
# 8     30s     2020-02-05    2020-02-21  1382400000000000
# 9     60s     2020-02-05    2020-02-29  2073600000000000
# 10    50s     2020-02-06    2020-02-29  1987200000000000
# 11    20s     2020-02-07    2020-02-27  1728000000000000
# 13    60s     2020-02-16    2020-03-12  2160000000000000
# 15    70s     2020-02-19    2020-03-11  1814400000000000
# 16    70s     2020-02-20    2020-03-01   864000000000000
# ...

# %%
dataP3 = dataP2.groupby('age').mean()
dataP3
# Out:
#               days
# age
# 0s    2.119074e+15
# 100s  5.702400e+15
# 10s   1.798449e+15
# 20s   2.028816e+15
# 30s   2.003989e+15
# 40s   2.043485e+15
# 50s   2.063232e+15
# 60s   2.318317e+15
# 70s   2.834545e+15
# 80s   3.000960e+15
# 90s   2.487086e+15

# %%
dataP3["days"] = dataP3["days"].astype('datetime64[ns]')
dataP3
# Out:
#                               days
# age
# 0s   1970-01-25 12:37:53.684210526
# 100s 1970-03-08 00:00:00.000000000
# 10s  1970-01-21 19:34:09.230769230
# 20s  1970-01-24 11:33:35.647921760
# 30s  1970-01-24 04:39:48.625592417
# 40s  1970-01-24 15:38:05.477178423
# 50s  1970-01-24 21:07:12.000000000
# 60s  1970-01-27 19:58:36.763005780
# 70s  1970-02-02 19:22:24.578313253
# 80s  1970-02-04 17:36:00.000000000
# 90s  1970-01-29 18:51:25.714285714
