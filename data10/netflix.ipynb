# %%
import pandas as pd

# %%
df = pd.read_csv('../data/netflix_titles.csv')
df
# Out:
#      show_id     type                                        title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                         7:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
df2 = df[df['release_year'] == 2016]
df2
# Out:
#      show_id     type                                              title  \
# 1         s2    Movie                                               7:19
# 5         s6  TV Show                                                 46
# 35       s36    Movie                                          #Rucker50
# 37       s38    Movie                                         #Selfie 69
# 38       s39  TV Show                                แผนร้ายนายเจ้าเล่ห์
# 54       s55    Movie                                         100 Meters
# 56       s57    Movie           100 Years: One Woman's Fight for Justice
# 66       s67    Movie                                               13TH
# 70       s71    Movie                              14 Minutes from Earth
# 74       s75    Movie              1898: Our Last Men in the Philippines
# 83       s84    Movie                                 20th Century Women
# 88       s89    Movie                               2307: Winter's Dream
# ...

# %%
df2.shape
# Out:
# (882, 12)

# %%
df2
# Out:
#      show_id     type                                              title  \
# 1         s2    Movie                                               7:19
# 5         s6  TV Show                                                 46
# 35       s36    Movie                                          #Rucker50
# 37       s38    Movie                                         #Selfie 69
# 38       s39  TV Show                                แผนร้ายนายเจ้าเล่ห์
# 54       s55    Movie                                         100 Meters
# 56       s57    Movie           100 Years: One Woman's Fight for Justice
# 66       s67    Movie                                               13TH
# 70       s71    Movie                              14 Minutes from Earth
# 74       s75    Movie              1898: Our Last Men in the Philippines
# 83       s84    Movie                                 20th Century Women
# 88       s89    Movie                               2307: Winter's Dream
# ...

# %%
df.groupby(['show_id'])['release_year'].transform('sum')
# Out:
# 0       2020
# 1       2016
# 2       2011
# 3       2009
# 4       2008
# 5       2016
# 6       2019
# 7       1997
# 8       2019
# 9       2008
# 10      2017
# 11      2018
# 12      2019
# 13      2018
# 14      2019
# 15      2014
# 16      2018
# 17      2018
# 18      2019
# 19      2017
# 20      2018
# 21      2018
# 22      2017
# 23      2017
# 24      2020
# 25      2015
# 26      2020
# 27      2020
# 28      2019
# 29      2020
#         ...
# 7757    2006
# 7758    2008
# 7759    2016
# 7760    2005
# 7761    2014
# 7762    2014
# 7763    2009
# 7764    2018
# 7765    2018
# 7766    2016
# 7767    2012
# 7768    2016
# 7769    2011
# 7770    2015
# 7771    2018
# 7772    2016
# 7773    2016
# 7774    2007
# 7775    2018
# 7776    2011
# 7777    2018
# 7778    2009
# 7779    2019
# 7780    2018
# 7781    2006
# 7782    2005
# 7783    2015
# 7784    2019
# 7785    2019
# 7786    2019
# Name: release_year, Length: 7787, dtype: int64

# %%
pd2 = pd.pivot_table(df, index = ['show_id'], values = 'release_year', aggfunc = 'sum')
pd2
# Out:
#          release_year
# show_id
# s1               2020
# s10              2008
# s100             2016
# s1000            2016
# s1001            2017
# s1002            2013
# s1003            1999
# s1004            2010
# s1005            2005
# s1006            2017
# s1007            2020
# s1008            2018
# s1009            2016
# s101             2009
# s1010            2013
# s1011            2007
# s1012            2018
# s1013            1991
# s1014            2015
# s1015            2017
# s1016            2020
# s1017            1973
# s1018            2014
# s1019            2018
# s102             2018
# s1020            2018
# s1021            2016
# s1022            2018
# s1023            2011
# s1024            2018
# ...               ...
# s972             2018
# s973             2017
# s974             2006
# s975             2008
# s976             2010
# s977             2016
# s978             2016
# s979             2015
# s98              2003
# ...

# %%
type(pd2)
# Out:
# pandas.core.frame.DataFrame
