# %%
import pandas as pd

# %%
dates = pd.date_range('20200310', periods=10)
dates
# Out:
# DatetimeIndex(['2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#                '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#                '2020-03-18', '2020-03-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=['createDt', 'gubun', 'qurRate', 'seq'])
df
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220
# 2020-03-13  1.637447  0.878001  0.302988 -0.848202
# 2020-03-14  0.178233  0.217980  0.909275 -0.455522
# 2020-03-15 -0.466438 -0.912110  1.428673  1.759293
# 2020-03-16 -1.453345 -0.189080  0.794860 -0.551436
# 2020-03-17  0.637003  0.096398 -0.088239 -1.435627
# 2020-03-18 -0.057268 -0.239062  1.077272 -1.019759
# 2020-03-19  1.875872  0.327454  2.030885  0.001967

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['createDt', 'gubun', 'qurRate', 'seq'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#                '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#                '2020-03-18', '2020-03-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.values
# Out:
# array([[-6.73455892e-01, -1.30842100e+00,  2.13905584e-01,
#          7.90202553e-01],
#        [-3.54275051e-01,  1.25613120e+00, -2.69306200e+00,
#          2.14833956e+00],
#        [ 1.39241324e-01, -2.20089105e-01,  8.53663734e-01,
#         -2.25220098e-01],
#        [ 1.63744681e+00,  8.78000533e-01,  3.02988338e-01,
#         -8.48201930e-01],
#        [ 1.78232915e-01,  2.17979672e-01,  9.09274784e-01,
#         -4.55521645e-01],
#        [-4.66437658e-01, -9.12109630e-01,  1.42867324e+00,
#          1.75929288e+00],
#        [-1.45334527e+00, -1.89079753e-01,  7.94860239e-01,
#         -5.51436030e-01],
#        [ 6.37002856e-01,  9.63976406e-02, -8.82387132e-02,
#         -1.43562654e+00],
#        [-5.72679358e-02, -2.39061575e-01,  1.07727151e+00,
#         -1.01975943e+00],
#        [ 1.87587189e+00,  3.27453631e-01,  2.03088531e+00,
#          1.96739593e-03]])

# %%
df.describe()
# Out:
#         createDt      gubun    qurRate        seq
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.146301  -0.009280   0.483022   0.016404
# std     1.019538   0.759910   1.272716   1.188598
# min    -1.453345  -1.308421  -2.693062  -1.435627
# 25%    -0.438397  -0.234318   0.236176  -0.774010
# 50%     0.040987  -0.046341   0.824262  -0.340371
# 75%     0.522310   0.300085   1.035272   0.593144
# max     1.875872   1.256131   2.030885   2.148340

# %%
df.sort_values(by='createDt') #오름차순 정렬
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-16 -1.453345 -0.189080  0.794860 -0.551436
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-15 -0.466438 -0.912110  1.428673  1.759293
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-18 -0.057268 -0.239062  1.077272 -1.019759
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220
# 2020-03-14  0.178233  0.217980  0.909275 -0.455522
# 2020-03-17  0.637003  0.096398 -0.088239 -1.435627
# 2020-03-13  1.637447  0.878001  0.302988 -0.848202
# 2020-03-19  1.875872  0.327454  2.030885  0.001967

# %%
df.sort_values(by='createDt', ascending=False) #내림차순 정렬
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-19  1.875872  0.327454  2.030885  0.001967
# 2020-03-13  1.637447  0.878001  0.302988 -0.848202
# 2020-03-17  0.637003  0.096398 -0.088239 -1.435627
# 2020-03-14  0.178233  0.217980  0.909275 -0.455522
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220
# 2020-03-18 -0.057268 -0.239062  1.077272 -1.019759
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-15 -0.466438 -0.912110  1.428673  1.759293
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-16 -1.453345 -0.189080  0.794860 -0.551436

# %%
df['createDt'] # createDt컬럼만 가져오기
# Out:
# 2020-03-10   -0.673456
# 2020-03-11   -0.354275
# 2020-03-12    0.139241
# 2020-03-13    1.637447
# 2020-03-14    0.178233
# 2020-03-15   -0.466438
# 2020-03-16   -1.453345
# 2020-03-17    0.637003
# 2020-03-18   -0.057268
# 2020-03-19    1.875872
# Freq: D, Name: createDt, dtype: float64

# %%
type(df.createDt)
# Out:
# pandas.core.series.Series

# %%
df['createDt']
# Out:
# 2020-03-10   -0.673456
# 2020-03-11   -0.354275
# 2020-03-12    0.139241
# 2020-03-13    1.637447
# 2020-03-14    0.178233
# 2020-03-15   -0.466438
# 2020-03-16   -1.453345
# 2020-03-17    0.637003
# 2020-03-18   -0.057268
# 2020-03-19    1.875872
# Freq: D, Name: createDt, dtype: float64

# %%
df[0:3]
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220

# %%
df.iloc[0:3]
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220

# %%
df.loc['2020-03-10']
# Out:
# createDt   -0.673456
# gubun      -1.308421
# qurRate     0.213906
# seq         0.790203
# Name: 2020-03-10 00:00:00, dtype: float64

# %%
df.loc['2020-03-10', 'createDt']
# Out:
# -0.6734558921886923

# %%
df.loc['2020-03-10', ['createDt', 'seq']]
# Out:
# createDt   -0.673456
# seq         0.790203
# Name: 2020-03-10 00:00:00, dtype: float64

# %%
df.loc[ : , 'createDt']
# Out:
# 2020-03-10   -0.673456
# 2020-03-11   -0.354275
# 2020-03-12    0.139241
# 2020-03-13    1.637447
# 2020-03-14    0.178233
# 2020-03-15   -0.466438
# 2020-03-16   -1.453345
# 2020-03-17    0.637003
# 2020-03-18   -0.057268
# 2020-03-19    1.875872
# Freq: D, Name: createDt, dtype: float64

# %%
df.loc[ : , ['createDt', 'seq']]
# Out:
#             createDt       seq
# 2020-03-10 -0.673456  0.790203
# 2020-03-11 -0.354275  2.148340
# 2020-03-12  0.139241 -0.225220
# 2020-03-13  1.637447 -0.848202
# 2020-03-14  0.178233 -0.455522
# 2020-03-15 -0.466438  1.759293
# 2020-03-16 -1.453345 -0.551436
# 2020-03-17  0.637003 -1.435627
# 2020-03-18 -0.057268 -1.019759
# 2020-03-19  1.875872  0.001967

# %%
df.loc[ : , 'createDt' : 'seq']
# Out:
#             createDt     gubun   qurRate       seq
# 2020-03-10 -0.673456 -1.308421  0.213906  0.790203
# 2020-03-11 -0.354275  1.256131 -2.693062  2.148340
# 2020-03-12  0.139241 -0.220089  0.853664 -0.225220
# 2020-03-13  1.637447  0.878001  0.302988 -0.848202
# 2020-03-14  0.178233  0.217980  0.909275 -0.455522
# 2020-03-15 -0.466438 -0.912110  1.428673  1.759293
# 2020-03-16 -1.453345 -0.189080  0.794860 -0.551436
# 2020-03-17  0.637003  0.096398 -0.088239 -1.435627
# 2020-03-18 -0.057268 -0.239062  1.077272 -1.019759
# 2020-03-19  1.875872  0.327454  2.030885  0.001967

# %%
corona = pd.read_excel('../data/COVID_Korea_demo.xls')
corona
# Out:
#       confCase  confCaseRate   createDt  criticalRate  death  deathRate  \
# 0         1927          3.39 2020-12-27          0.00      0       0.00
# 1         3544          6.23 2020-12-27          0.00      0       0.00
# 2         9281         16.32 2020-12-27          0.00      0       0.00
# 3         7226         12.71 2020-12-27          0.04      3       0.37
# 4         8033         14.12 2020-12-27          0.09      7       0.87
# 5        10648         18.72 2020-12-27          0.28     30       3.71
# 6         8939         15.72 2020-12-27          1.05     94      11.63
# 7         4472          7.86 2020-12-27          5.28    236      29.21
# 8         2802          4.93 2020-12-27         15.63    438      54.21
# 9        29301         51.52 2020-12-27          1.35    397      49.13
# 10       27571         48.48 2020-12-27          1.49    411      50.87
# 11        1891          3.38 2020-12-26          0.00      0       0.00
# ...

# %%
corona = pd.read_excel('../data/COVID_Korea_demo.xls', header=0) #맨 첫행 날아감
corona
# Out:
#       confCase  confCaseRate   createDt  criticalRate  death  deathRate  \
# 0         1927          3.39 2020-12-27          0.00      0       0.00
# 1         3544          6.23 2020-12-27          0.00      0       0.00
# 2         9281         16.32 2020-12-27          0.00      0       0.00
# 3         7226         12.71 2020-12-27          0.04      3       0.37
# 4         8033         14.12 2020-12-27          0.09      7       0.87
# 5        10648         18.72 2020-12-27          0.28     30       3.71
# 6         8939         15.72 2020-12-27          1.05     94      11.63
# 7         4472          7.86 2020-12-27          5.28    236      29.21
# 8         2802          4.93 2020-12-27         15.63    438      54.21
# 9        29301         51.52 2020-12-27          1.35    397      49.13
# 10       27571         48.48 2020-12-27          1.49    411      50.87
# 11        1891          3.38 2020-12-26          0.00      0       0.00
# ...

# %%
corona = pd.read_excel('../data/COVID_Korea_demo.xls', header=0, usecols='A:M')
corona
# Out:
#       confCase  confCaseRate   createDt  criticalRate  death  deathRate  \
# 0         1927          3.39 2020-12-27          0.00      0       0.00
# 1         3544          6.23 2020-12-27          0.00      0       0.00
# 2         9281         16.32 2020-12-27          0.00      0       0.00
# 3         7226         12.71 2020-12-27          0.04      3       0.37
# 4         8033         14.12 2020-12-27          0.09      7       0.87
# 5        10648         18.72 2020-12-27          0.28     30       3.71
# 6         8939         15.72 2020-12-27          1.05     94      11.63
# 7         4472          7.86 2020-12-27          5.28    236      29.21
# 8         2802          4.93 2020-12-27         15.63    438      54.21
# 9        29301         51.52 2020-12-27          1.35    397      49.13
# 10       27571         48.48 2020-12-27          1.49    411      50.87
# 11        1891          3.38 2020-12-26          0.00      0       0.00
# ...

# %%
col_names = ['1','2','3','4','5','6','7','8','9']
corona = pd.read_excel('../data/COVID_Korea_demo.xls',
                     header=1,
                     usecols='A:I',
                     names=col_names
                    )
corona
# Out:
#           1      2          3      4    5      6       7     8   9
# 0      3544   6.23 2020-12-27   0.00    0   0.00   10-19  5696 NaN
# 1      9281  16.32 2020-12-27   0.00    0   0.00   20-29  5695 NaN
# 2      7226  12.71 2020-12-27   0.04    3   0.37   30-39  5694 NaN
# 3      8033  14.12 2020-12-27   0.09    7   0.87   40-49  5693 NaN
# 4     10648  18.72 2020-12-27   0.28   30   3.71   50-59  5692 NaN
# 5      8939  15.72 2020-12-27   1.05   94  11.63   60-69  5691 NaN
# 6      4472   7.86 2020-12-27   5.28  236  29.21   70-79  5690 NaN
# 7      2802   4.93 2020-12-27  15.63  438  54.21  80-100  5689 NaN
# 8     29301  51.52 2020-12-27   1.35  397  49.13       0  5688 NaN
# 9     27571  48.48 2020-12-27   1.49  411  50.87       0  5687 NaN
# 10     1891   3.38 2020-12-26   0.00    0   0.00     0-9  5675 NaN
# 11     3483   6.23 2020-12-26   0.00    0   0.00   10-19  5674 NaN
# 12     9170  16.40 2020-12-26   0.00    0   0.00   20-29  5673 NaN
# ...

# %%
col_names = ['확진자','확진률','날짜',
             '위험률','사망','사망률',
             '구분','인원','업데이트날짜']
corona = pd.read_excel('../data/COVID_Korea_demo.xls',
                     header=1,
                     usecols='A:I',
                     names=col_names
                    )
corona
# Out:
#         확진자    확진률         날짜    위험률   사망    사망률      구분    인원  업데이트날짜
# 0      3544   6.23 2020-12-27   0.00    0   0.00   10-19  5696     NaN
# 1      9281  16.32 2020-12-27   0.00    0   0.00   20-29  5695     NaN
# 2      7226  12.71 2020-12-27   0.04    3   0.37   30-39  5694     NaN
# 3      8033  14.12 2020-12-27   0.09    7   0.87   40-49  5693     NaN
# 4     10648  18.72 2020-12-27   0.28   30   3.71   50-59  5692     NaN
# 5      8939  15.72 2020-12-27   1.05   94  11.63   60-69  5691     NaN
# 6      4472   7.86 2020-12-27   5.28  236  29.21   70-79  5690     NaN
# 7      2802   4.93 2020-12-27  15.63  438  54.21  80-100  5689     NaN
# 8     29301  51.52 2020-12-27   1.35  397  49.13       0  5688     NaN
# 9     27571  48.48 2020-12-27   1.49  411  50.87       0  5687     NaN
# 10     1891   3.38 2020-12-26   0.00    0   0.00     0-9  5675     NaN
# 11     3483   6.23 2020-12-26   0.00    0   0.00   10-19  5674     NaN
# ...

# %%
corona = corona.drop(['확진자', '확진률', '위험률', '사망률', '인원', '업데이트날짜'], axis=1)
corona
# Out:
#              날짜   사망      구분
# 0    2020-12-27    0   10-19
# 1    2020-12-27    0   20-29
# 2    2020-12-27    3   30-39
# 3    2020-12-27    7   40-49
# 4    2020-12-27   30   50-59
# 5    2020-12-27   94   60-69
# 6    2020-12-27  236   70-79
# 7    2020-12-27  438  80-100
# 8    2020-12-27  397       0
# 9    2020-12-27  411       0
# 10   2020-12-26    0     0-9
# 11   2020-12-26    0   10-19
# 12   2020-12-26    0   20-29
# 13   2020-12-26    3   30-39
# 14   2020-12-26    7   40-49
# 15   2020-12-26   30   50-59
# 16   2020-12-26   92   60-69
# 17   2020-12-26  234   70-79
# 18   2020-12-26  427  80-100
# 19   2020-12-26  389       0
# 20   2020-12-26  404       0
# 21   2020-12-25    0     0-9
# 22   2020-12-25    0   10-19
# 23   2020-12-25    0   20-29
# 24   2020-12-25    3   30-39
# 25   2020-12-25    7   40-49
# 26   2020-12-25   30   50-59
# 27   2020-12-25   90   60-69
# 28   2020-12-25  227   70-79
# 29   2020-12-25  416  80-100
# ...         ...  ...     ...
# ...

# %%
covid = pd.pivot_table(corona, index = ['구분'], values = '사망', aggfunc = 'sum')
covid
# Out:
#            사망
# 구분
# 0       95344
# 0-9         1
# 10-19     298
# 20-29       0
# 30-39     517
# 40-49     961
# 50-59    4701
# 60-69   12007
# 70-79   29361
# 80-100  47479

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc # 한글 처리
f_path = 'C:/Windows/Fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=f_path).get_name()
rc('font', family = font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
ex = [0, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02]

# %%
# corona['사망'].plot.pie(explode= ex)
covid['사망'].plot.pie()
